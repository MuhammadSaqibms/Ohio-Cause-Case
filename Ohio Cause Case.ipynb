# %%
import matplotlib.pyplot as plt

# %%
cause = 'Chronic','Diseases','Unintentional Injuries','Alzheimers','Infuenza','Others'
percentile = [65,5,4,2,1,26]
plt.figure(figsize=(10,10))
explode = (0,0.5,0,0,0,0,0)
plt.pie(percentile,labels=cause,autopct='%.1f%%',startangle=70)
plt.axis('equal')
plt.title('OHIO State - 2012: Leading Causes of Death')
plt.show()
